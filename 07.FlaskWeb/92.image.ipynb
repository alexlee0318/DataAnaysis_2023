# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open('static/img/루피가로3.jpg')
plt.imshow(img), plt.axis('off');

# %%
np.array(img).shape
# Out:
# (319, 564, 3)

# %%
h, w, _ = np.array(img).shape

# %%
if h > w:
    width, height  = w, w   # 작은 값으로
else:
    width, height = h, h

# %%
diff = abs(h - w) // 2

# %%
if w > h:           # landscape image
    final_img = np.array(img)[:, diff:diff+h, :]
else:               # portrait image
    final_img = np.array(img)[diff:diff+w, :, :]

# %%
new_img = Image.fromarray(final_img)
plt.imshow(new_img);

# %%
import image_util as iu
plt.imshow(iu.center_image(img))

# %%
# img.save('static/data/profile.png', format='png')  --> 원본으로 저장
iu.center_image(img).save('static/data/profile.png', format='png') # 수정한 이미지로 저장
