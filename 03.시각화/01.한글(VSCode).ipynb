# %% [markdown]
# #### Matplotlob 한글사용법 (VSCode)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - 라인플롯

# %%
plt.plot([0,1,2,3],[0,1,4,9])    # X, Y
plt.title('Line plot')          # 제목
plt.grid()                      #격자선
plt.show()

# %% [markdown]
# - 한글패치 방법

# %%
# 방법 1
plt.rcParams['font.family'] = 'Malgun Gothic'   # 맑은고딕으로 폰트지정

# %%
plt.plot([0,1,2,3],[0,1,4,9])    # X, Y
plt.title('라인플롯')          # 제목
plt.grid()                      #격자선

# %% [markdown]
# - 다양한 폰트 설정하는 법

# %%
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 import matplotlib.font_manager as fm
# ----> 2 fm.get_fontconfig_fonts()
#
# AttributeError: module 'matplotlib.font_manager' has no attribute 'get_fontconfig_fonts'

# %%
import matplotlib.font_manager

matplotlib.font_manager._rebuild()
sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist if f.name.startswith("Nanum")])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 import matplotlib.font_manager
# ----> 3 matplotlib.font_manager._rebuild()
#       4 sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist if f.name.startswith("Nanum")])
#
# AttributeError: module 'matplotlib.font_manager' has no attribute '_rebuild'
