# %% [markdown]
# ### 2. 여러가지 플롯

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False      # minus오류 없애는

# %% [markdown]
# ``` 포토샵의 Layer 사용하는 방식과 같은 방식```

# %% [markdown]
# 1. Bar Chart

# %%
# 안좋은 예
y, x = [2, 3, 1],[0, 1, 2]
plt.title('Bar Chart')
plt.bar(x, y)
plt.xticks(x, ['가','나','다']), plt.yticks(sorted(y))
plt.xlabel('가나다'), plt.ylabel('빈도수')
# Out:
# (Text(0.5, 0, '가나다'), Text(0, 0.5, '빈도수'))

# %%
# 더 나은 예 
s = pd.Series(np.random.rand(10), index=list('abcdefghij'))
plt.bar(s.index, s.values)
plt.title('Bar chart')
plt.yticks([0, 0.2, 0.4, 0.6, 0.8]), plt.xticks([]), plt.grid() # grid 정돈- x축에는 안넣겠다
plt.show()

# %%
s.plot(kind='bar')
plt.show()

# %%
# 더 나은 예 
df = pd.DataFrame(np.random.rand(20).reshape(10,2),
                  index=list('abcdefghij'), columns=['M','N'])
plt.bar(df.index, df.M.values)
plt.title('Bar chart')
plt.show()

# %% [markdown]
# - 타이타닉 데이터로 누운 차트 만들기

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
s = titanic['class'].value_counts()
plt.figure(figsize=(3,1))
plt.barh(s.index, s.values) # barh에는 x, y 밸류 주면 됨
plt.title('타이타닉호의 선실별 승객수')
plt.show()

# %% [markdown]
# #### 2. Pie Chart

# %%
# 기본모양
ratio = [10, 15, 20, 25]        # 합이 100이 아니어도 됨
labels = ['감','귤','배','밤 ']
plt.figure(figsize=(5,2))
plt.pie(ratio, labels=labels, autopct='%.1f%%') #소숫점 1째자리, %기호 쓰겠음
plt.title('파이 차트')
plt.show()

# %%
colors = ['yellowgreen', 'gold','lightskyblue','lightcoral']
explode = (0, 0.1, 0, 0)
plt.figure(figsize=(5,2))
plt.pie(ratio, labels=labels, autopct='%.1f%%', colors=colors, explode=explode,
        startangle=90, shadow=True)
plt.title('파이차트')
# Out:
# Text(0.5, 1.0, '파이차트')

# %% [markdown]
# 3. 히스토그램

# %%
np.random.seed(2023)
x = np.random.randn(1000)   # randn: 표준정규분포에 해당되는 random 넘버
plt.figure(figsize=(4,3))
plt.title('히스토그램')
a, b, p = plt.hist(x, bins=10)    # bins: 10개 구간으로 쪼개기
plt.show()

# %%
# 각 구간에 속한 돗수 (구간 별 값이 몇개 있는지)
a
# Out:
# array([  4.,  24.,  57., 135., 194., 210., 193., 116.,  46.,  21.])

# %%
# 경계값
b
# Out:
# array([-3.12153215, -2.54393821, -1.96634427, -1.38875033, -0.81115639,
#        -0.23356245,  0.3440315 ,  0.92162544,  1.49921938,  2.07681332,
#         2.65440726])

# %% [markdown]
# 4. 산점도(Scatter plot) : x, y의 관계를 눈으로 보기
#     -   2차원 데이터 즉, 두 개의 실수 데이터 집합의 상관관계를 살펴보려면 scatter 명령으로 스캐터 플롯을 그린다. 스캐터 플롯의 점 하나의 위치는 데이터 하나의 x, y 값이다.

# %%
np.random.seed(2023)
X, Y = np.random.normal(2, 2, 100), np.random.randn(100)    # 평균2, 표준편차 2 인 숫자 100개
plt.figure(figsize=(4,2))
plt.scatter(X, Y)
plt.title('산점도_X,Y관계')
plt.show()

# %%
colors = np.random.rand(100)    # 색상값 범위
plt.figure(figsize=(4,2))
plt.scatter(X, Y, c=colors, alpha=0.5) # 색상, 투명도
plt.title('색상을 준 산점도')
plt.show()

# %%
size = 500 * np.random.rand(100)    # 크기
plt.figure(figsize=(5,3))
plt.scatter(X, Y, s=size, c=colors, alpha=0.5) # 크기, 색상, 투명도
plt.title('색상을 준 산점도')
plt.show()

# %% [markdown]
# #### 5. 이미지 보기

# %%
from PIL import Image
plt.figure(figsize=(3,3))
img = Image.open('C:/Users/YONSAI/Pictures/감자.jpg')
plt.imshow(img)

# %%
plt.figure(figsize=(5,3))
plt.imshow(img); plt.axis('off');

# %% [markdown]
# 6. Boxplot

# %%
iris = sns.load_dataset('iris')
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
ssl = iris[iris.species == 'setosa'].sepal_length
ssw = iris[iris.species == 'setosa'].sepal_width
plt.boxplot((ssl, ssw), labels=['sepal length', 'sepal width'])
plt.title('Setosa 품종의 꽃받침 길이, 너비')
plt.show()
